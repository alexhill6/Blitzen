# %%
import sys
import pandas as pd
import numpy as np

#scorecard_df = pd.read_csv(sys.argv[1])
ipeds_df = pd.read_csv("/Users/betsyfrdmn/Desktop/Blitzen Group Project/Blitzen/College_Scorecard_export/hd2021.csv", encoding="latin1")

#year = 2019 # int(sys.argv[1][-14:-10]) + 1
ipeds_df['YEAR'] = 2021
ipeds_df.head()
# Out:
#    UNITID                               INSTNM  \
# 0  100654             Alabama A & M University
# 1  100663  University of Alabama at Birmingham
# 2  100690                   Amridge University
# 3  100706  University of Alabama in Huntsville
# 4  100724             Alabama State University
#
#                                               IALIAS  \
# 0                                               AAMU
# 1                                                UAB
# 2  Southern Christian University  Regions University
# 3              UAH  University of Alabama Huntsville
# 4
#
#                              ADDR        CITY STABBR         ZIP  FIPS  \
# 0            4900 Meridian Street      Normal     AL       35762     1
# 1  Administration Bldg Suite 1070  Birmingham     AL  35294-0110     1
# 2                  1200 Taylor Rd  Montgomery     AL  36117-3553     1
# 3                 301 Sparkman Dr  Huntsville     AL       35899     1
# 4            915 S Jackson Street  Montgomery     AL  36104-0271     1
#
#    OBEREG                   CHFNM  ...  CSA NECTA  COUNTYCD  \
# 0       5  Dr. Andrew Hugine, Jr.  ...  290    -2      1089
# 1       5            Ray L. Watts  ...  142    -2      1073
# 2       5        Michael C.Turner  ...  388    -2      1101
# 3       5           Darren Dawson  ...  290    -2      1089
# 4       5         Quinton T. Ross  ...  388    -2      1101
#
#             COUNTYNM  CNGDSTCD   LONGITUD   LATITUDE DFRCGID DFRCUSCG  YEAR
# 0     Madison County       105 -86.568502  34.783368     109        1  2021
# 1   Jefferson County       107 -86.799345  33.505697      93        1  2021
# 2  Montgomery County       102 -86.174010  32.362609     127        2  2021
# 3     Madison County       105 -86.640449  34.724557      93        2  2021
# 4  Montgomery County       107 -86.295677  32.364317      99        1  2021
#
# [5 rows x 75 columns]

# %%
institution_ipeds_info_df = ipeds_df[['UNITID', 'YEAR','INSTNM', 'ADDR','CITY','STABBR','ZIP','FIPS',
                                      'COUNTYCD','COUNTYNM','CBSA','CBSATYPE','CSA','LATITUDE','LONGITUD',
                                      'C21BASIC','C21IPUG','C21IPGRD','C21UGPRF','C21ENPRF','C21SZSET']]
institution_ipeds_info_df.head()
# Out:
#    UNITID  YEAR                               INSTNM  \
# 0  100654  2021             Alabama A & M University
# 1  100663  2021  University of Alabama at Birmingham
# 2  100690  2021                   Amridge University
# 3  100706  2021  University of Alabama in Huntsville
# 4  100724  2021             Alabama State University
#
#                              ADDR        CITY STABBR         ZIP  FIPS  \
# 0            4900 Meridian Street      Normal     AL       35762     1
# 1  Administration Bldg Suite 1070  Birmingham     AL  35294-0110     1
# 2                  1200 Taylor Rd  Montgomery     AL  36117-3553     1
# 3                 301 Sparkman Dr  Huntsville     AL       35899     1
# 4            915 S Jackson Street  Montgomery     AL  36104-0271     1
#
#    COUNTYCD           COUNTYNM  ...  CBSATYPE  CSA   LATITUDE   LONGITUD  \
# 0      1089     Madison County  ...         1  290  34.783368 -86.568502
# 1      1073   Jefferson County  ...         1  142  33.505697 -86.799345
# 2      1101  Montgomery County  ...         1  388  32.362609 -86.174010
# 3      1089     Madison County  ...         1  290  34.724557 -86.640449
# 4      1101  Montgomery County  ...         1  388  32.364317 -86.295677
#
#    C21BASIC  C21IPUG  C21IPGRD  C21UGPRF  C21ENPRF  C21SZSET
# 0        18       16        18        10         4        14
# 1        15       14        14         9         5        15
# 2        20       20        18         5         6         6
# 3        15       17        17        15         4        13
# 4        17       13        18        10         3        14
#
# [5 rows x 21 columns]

# %% [markdown]
#     UNITID INTEGER NOT NULL,
#     YEAR SMALLINT NOT NULL,
#     INSTNM TEXT NOT NULL,
#     ADDR TEXT,
#     CITY TEXT,
#     STABBR CHAR(2),
#     ZIP VARCHAR(10),
#     FIPS VARCHAR(5),
#     COUNTYCD VARCHAR(5),
#     COUNTYNM TEXT,
#     CBSA VARCHAR(5),
#     CBSATYPE TEXT CHECK (CBSATYPE IN ('Metropolitan','Micropolitan')
#                          OR CBSATYPE IS NULL),
#     CSA VARCHAR(3),
#     LATITUDE REAL,
#     LONGITUD REAL,
#     C21BASIC TEXT,
#     C21IPUG TEXT,
#     C21IPGRD TEXT,
#     C21UGPRF TEXT,
#     C21ENPRF TEXT,
#     C21SZSET TEXT,

# %%
institution_ipeds_info_df = institution_ipeds_info_df.replace({pd.NA: None, np.nan: None})

# %%
print(len(institution_ipeds_info_df))
print(institution_ipeds_info_df.isna().sum())
# Out:
# 6289
# UNITID      0
# YEAR        0
# INSTNM      0
# ADDR        0
# CITY        0
# STABBR      0
# ZIP         0
# FIPS        0
# COUNTYCD    0
# COUNTYNM    0
# CBSA        0
# CBSATYPE    0
# CSA         0
# LATITUDE    0
# LONGITUD    0
# C21BASIC    0
# C21IPUG     0
# C21IPGRD    0
# C21UGPRF    0
# C21ENPRF    0
# C21SZSET    0
# dtype: int64

# %%
from sqlalchemy import create_engine
import importlib.util
import credentials_copy
username = "elliehua"
database = "elliehua"
password = credentials_copy.DB_PASSWORD
db_url = f"postgresql://" + username + ":" + password + "@debprodserver.postgres.database.azure.com:5432/" + database
engine = create_engine(db_url)

# %%
# %load_ext sql
# %sql engine
# Out:
# The sql extension is already loaded. To reload it, use:
#   %reload_ext sql

# %%
# %sql -x;
# Out:
# RuntimeError: Could not close connection because it was not found amongst these: ['postgresql://elliehua:***@debprodserver.postgres.database.azure.com:5432/elliehua']

# %%
# %%sql
# select *
# from INFORMATION_SCHEMA.TABLE_CONSTRAINTS
# WHERE TABLE_NAME = 'institution_ipeds_info';
# Out:
# Running query in 'postgresql://elliehua:***@debprodserver.postgres.database.azure.com:5432/elliehua'
# 7 rows affected.
# +--------------------+-------------------+---------------------------------------+---------------+--------------+------------------------+-----------------+---------------+--------------------+----------+----------------+
# | constraint_catalog | constraint_schema |            constraint_name            | table_catalog | table_schema |       table_name       | constraint_type | is_deferrable | initially_deferred | enforced | nulls_distinct |
# +--------------------+-------------------+---------------------------------------+---------------+--------------+------------------------+-----------------+---------------+--------------------+----------+----------------+
# |      elliehua      |       public      |             chk_inst_year             |    elliehua   |    public    | institution_ipeds_info |      CHECK      |       NO      |         NO         |   YES    |      None      |
# |      elliehua      |       public      |           fk_ipeds_scorecard          |    elliehua   |    public    | institution_ipeds_info |   FOREIGN KEY   |       NO      |         NO         |   YES    |      None      |
# |      elliehua      |       public      | institution_ipeds_info_cbsatype_check |    elliehua   |    public    | institution_ipeds_info |      CHECK      |       NO      |         NO         |   YES    |      None      |
# |      elliehua      |       public      |       pk_institution_ipeds_info       |    elliehua   |    public    | institution_ipeds_info |   PRIMARY KEY   |       NO      |         NO         |   YES    |      None      |
# |      elliehua      |       public      |         2200_44100_1_not_null         |    elliehua   |    public    | institution_ipeds_info |      CHECK      |       NO      |         NO         |   YES    |      None      |
# |      elliehua      |       public      |         2200_44100_2_not_null         |    elliehua   |    public    | institution_ipeds_info |      CHECK      |       NO      |         NO         |   YES    |      None      |
# |      elliehua      |       public      |         2200_44100_3_not_null         |    elliehua   |    public    | institution_ipeds_info |      CHECK      |       NO      |         NO         |   YES    |      None      |
# +--------------------+-------------------+---------------------------------------+---------------+--------------+------------------------+-----------------+---------------+--------------------+----------+----------------+

# %%
# insert_dataframe.py
import psycopg2
import pandas as pd
import credentials_copy

def insert_dataframe(df, table_name, host_name, db_name, user_name, pw):
    """
    Inserts all rows of a DataFrame into a SQL table using parameterized
    prepared statements. Rolls back if any row fails.
    """

    # Create column list: ("col1", "col2", ...)
    columns = list(df.columns)
    col_names = ", ".join(columns)
    placeholders = ", ".join([f"%({c})s" for c in columns])  # named parameters

    insert_sql = f"""
        INSERT INTO {table_name} ({col_names})
        VALUES ({placeholders});
    """
    fail_count = 0
    total_read = 0
    try:
        with psycopg2.connect(host=host_name, dbname=db_name, user=user_name, password=pw) as conn:
            with conn.cursor() as cur:

                for _, row in df.iterrows():
                    # Convert Series → dict for named placeholders
                    row_dict = row.to_dict()

                    try:
                        cur.execute(insert_sql, row_dict)

                    except psycopg2.errors.ForeignKeyViolation as e:
                        print(f"Foreign key violation on row: {row_dict}")
                        print(e)
                        conn.rollback()
                        #return
                        fail_count += 1
                    except Exception as e:
                        print(f"Error inserting row: {row_dict}")
                        print(e)
                        conn.rollback()
                        fail_count += 1
                        #return
                    
                    total_read += 1

                conn.commit()
                print(f"{total_read} rows read successfully.")
                print(f"{total_read - fail_count} rows loaded successfully.")
                print(f"{fail_count} rows unsuccessfully loaded.")

    except Exception as e:
        print("Connection or execution error:")
        print(e)


host="debprodserver.postgres.database.azure.com"
dbname=credentials_copy.DB_USER
user=credentials_copy.DB_USER
password=credentials_copy.DB_PASSWORD

insert_dataframe(institution_ipeds_info_df, "institution_ipeds_info", host, dbname, user, password)
# Out:
# Foreign key violation on row: {'UNITID': 100733, 'YEAR': 2021, 'INSTNM': 'University of Alabama System Office', 'ADDR': '500 University Blvd. East', 'CITY': 'Tuscaloosa', 'STABBR': 'AL', 'ZIP': '35401', 'FIPS': 1, 'COUNTYCD': 1125, 'COUNTYNM': 'Tuscaloosa County', 'CBSA': 46220, 'CBSATYPE': 1, 'CSA': -2, 'LATITUDE': 33.207015, 'LONGITUD': -87.529594, 'C21BASIC': -2, 'C21IPUG': -2, 'C21IPGRD': -2, 'C21UGPRF': -2, 'C21ENPRF': -2, 'C21SZSET': -2}
# insert or update on table "institution_ipeds_info" violates foreign key constraint "fk_ipeds_scorecard"
# DETAIL:  Key (unitid, year)=(100733, 2021) is not present in table "institution_scorecard_info".
#
# Foreign key violation on row: {'UNITID': 102058, 'YEAR': 2021, 'INSTNM': 'Selma University', 'ADDR': '1501 Lapsley St, Dinkins Hall', 'CITY': 'Selma', 'STABBR': 'AL', 'ZIP': '36701', 'FIPS': 1, 'COUNTYCD': 1047, 'COUNTYNM': 'Dallas County', 'CBSA': 42820, 'CBSATYPE': 2, 'CSA': 388, 'LATITUDE': 32.420387, 'LONGITUD': -87.032392, 'C21BASIC': -2, 'C21IPUG': -2, 'C21IPGRD': -2, 'C21UGPRF': -2, 'C21ENPRF': -2, 'C21SZSET': -2}
# insert or update on table "institution_ipeds_info" violates foreign key constraint "fk_ipeds_scorecard"
# DETAIL:  Key (unitid, year)=(102058, 2021) is not present in table "institution_scorecard_info".
#
# Foreign key violation on row: {'UNITID': 103529, 'YEAR': 2021, 'INSTNM': 'University of Alaska System of Higher Education', 'ADDR': '910 Yukon Drive, Suite 202 Butrovich Building', 'CITY': 'Fairbanks', 'STABBR': 'AK', 'ZIP': '99775-5000', 'FIPS': 2, 'COUNTYCD': 2090, 'COUNTYNM': 'Fairbanks North Star Borough', 'CBSA': 21820, 'CBSATYPE': 1, 'CSA': -2, 'LATITUDE': 64.857516, 'LONGITUD': -147.848969, 'C21BASIC': -2, 'C21IPUG': -2, 'C21IPGRD': -2, 'C21UGPRF': -2, 'C21ENPRF': -2, 'C21SZSET': -2}
# insert or update on table "institution_ipeds_info" violates foreign key constraint "fk_ipeds_scorecard"
# DETAIL:  Key (unitid, year)=(103529, 2021) is not present in table "institution_scorecard_info".
#
# Foreign key violation on row: {'UNITID': 104188, 'YEAR': 2021, 'INSTNM': 'Southwest University of Visual Arts-Tucson', 'ADDR': '20 E. Congress St.', 'CITY': 'Tucson', 'STABBR': 'AZ', 'ZIP': '85701', 'FIPS': 4, 'COUNTYCD': 4019, 'COUNTYNM': 'Pima County', 'CBSA': 46060, 'CBSATYPE': 1, 'CSA': 536, 'LATITUDE': 32.221702, 'LONGITUD': -110.970838, 'C21BASIC': -2, 'C21IPUG': -2, 'C21IPGRD': -2, 'C21UGPRF': -2, 'C21ENPRF': -2, 'C21SZSET': -2}
# insert or update on table "institution_ipeds_info" violates foreign key constraint "fk_ipeds_scorecard"
# DETAIL:  Key (unitid, year)=(104188, 2021) is not present in table "institution_scorecard_info".
#
# Foreign key violation on row: {'UNITID': 105136, 'YEAR': 2021, 'INSTNM': 'Maricopa Community College System Office', 'ADDR': '2411 W 14th St', 'CITY': 'Tempe', 'STABBR': 'AZ', 'ZIP': '85281-6942', 'FIPS': 4, 'COUNTYCD': 4013, 'COUNTYNM': 'Maricopa County', 'CBSA': 38060, 'CBSATYPE': 1, 'CSA': 429, 'LATITUDE': 33.412915, 'LONGITUD': -111.975786, 'C21BASIC': -2, 'C21IPUG': -2, 'C21IPGRD': -2, 'C21UGPRF': -2, 'C21ENPRF': -2, 'C21SZSET': -2}
# insert or update on table "institution_ipeds_info" violates foreign key constraint "fk_ipeds_scorecard"
# DETAIL:  Key (unitid, year)=(105136, 2021) is not present in table "institution_scorecard_info".
#
# Foreign key violation on row: {'UNITID': 108056, 'YEAR': 2021, 'INSTNM': 'University of Arkansas System Office', 'ADDR': '2404 N University', 'CITY': 'Little Rock', 'STABBR': 'AR', 'ZIP': '72207-3608', 'FIPS': 5, 'COUNTYCD': 5119, 'COUNTYNM': 'Pulaski County', 'CBSA': 30780, 'CBSATYPE': 1, 'CSA': 340, 'LATITUDE': 34.775996, 'LONGITUD': -92.343582, 'C21BASIC': -2, 'C21IPUG': -2, 'C21IPGRD': -2, 'C21UGPRF': -2, 'C21ENPRF': -2, 'C21SZSET': -2}
# insert or update on table "institution_ipeds_info" violates foreign key constraint "fk_ipeds_scorecard"
# DETAIL:  Key (unitid, year)=(108056, 2021) is not present in table "institution_scorecard_info".
#
# Foreign key violation on row: {'UNITID': 110501, 'YEAR': 2021, 'INSTNM': 'California State University-Chancellors Office', 'ADDR': 'Institutional Research & Analyses 401 Golden Shore, 6th Floor', 'CITY': 'Long Beach', 'STABBR': 'CA', 'ZIP': '90802-4210', 'FIPS': 6, 'COUNTYCD': 6037, 'COUNTYNM': 'Los Angeles County', 'CBSA': 31080, 'CBSATYPE': 1, 'CSA': 348, 'LATITUDE': 33.764338, 'LONGITUD': -118.201255, 'C21BASIC': -2, 'C21IPUG': -2, 'C21IPGRD': -2, 'C21UGPRF': -2, 'C21ENPRF': -2, 'C21SZSET': -2}
# insert or update on table "institution_ipeds_info" violates foreign key constraint "fk_ipeds_scorecard"
# DETAIL:  Key (unitid, year)=(110501, 2021) is not present in table "institution_scorecard_info".
#
# Foreign key violation on row: {'UNITID': 112376, 'YEAR': 2021, 'INSTNM': 'Coast Community College District Office', 'ADDR': '1370 Adams Ave.', 'CITY': 'Costa Mesa', 'STABBR': 'CA', 'ZIP': '92626', 'FIPS': 6, 'COUNTYCD': 6059, 'COUNTYNM': 'Orange County', 'CBSA': 31080, 'CBSATYPE': 1, 'CSA': 348, 'LATITUDE': 33.674004, 'LONGITUD': -117.916066, 'C21BASIC': -2, 'C21IPUG': -2, 'C21IPGRD': -2, 'C21UGPRF': -2, 'C21ENPRF': -2, 'C21SZSET': -2}
# insert or update on table "institution_ipeds_info" violates foreign key constraint "fk_ipeds_scorecard"
# DETAIL:  Key (unitid, year)=(112376, 2021) is not present in table "institution_scorecard_info".
#
# Foreign key violation on row: {'UNITID': 112817, 'YEAR': 2021, 'INSTNM': 'Contra Costa Community College District Office', 'ADDR': '500 Court St', 'CITY': 'Martinez', 'STABBR': 'CA', 'ZIP': '94553', 'FIPS': 6, 'COUNTYCD': 6013, 'COUNTYNM': 'Contra Costa County', 'CBSA': 41860, 'CBSATYPE': 1, 'CSA': 488, 'LATITUDE': 38.019072, 'LONGITUD': -122.135335, 'C21BASIC': -2, 'C21IPUG': -2, 'C21IPGRD': -2, 'C21UGPRF': -2, 'C21ENPRF': -2, 'C21SZSET': -2}
# insert or update on table "institution_ipeds_info" violates foreign key constraint "fk_ipeds_scorecard"
# DETAIL:  Key (unitid, year)=(112817, 2021) is not present in table "institution_scorecard_info".
#
# Foreign key violation on row: {'UNITID': 114831, 'YEAR': 2021, 'INSTNM': 'Foothill-De Anza Community College District', 'ADDR': '12345 El Monte Rd', 'CITY': 'Los Altos Hills', 'STABBR': 'CA', 'ZIP': '94022-4599', 'FIPS': 6, 'COUNTYCD': 6085, 'COUNTYNM': 'Santa Clara County', 'CBSA': 41940, 'CBSATYPE': 1, 'CSA': 488, 'LATITUDE': 37.361664, 'LONGITUD': -122.12796, 'C21BASIC': -2, 'C21IPUG': -2, 'C21IPGRD': -2, 'C21UGPRF': -2, 'C21ENPRF': -2, 'C21SZSET': -2}
# insert or update on table "institution_ipeds_info" violates foreign key constraint "fk_ipeds_scorecard"
# DETAIL:  Key (unitid, year)=(114831, 2021) is not present in table "institution_scorecard_info".
#
# Foreign key violation on row: {'UNITID': 115287, 'YEAR': 2021, 'INSTNM': 'Grossmont-Cuyamaca Community College District', 'ADDR': '8800 Grossmont College Dr', 'CITY': 'El Cajon', 'STABBR': 'CA', 'ZIP': '92020-1799', 'FIPS': 6, 'COUNTYCD': 6073, 'COUNTYNM': 'San Diego County', 'CBSA': 41740, 'CBSATYPE': 1, 'CSA': -2, 'LATITUDE': 32.815246, 'LONGITUD': -117.006277, 'C21BASIC': -2, 'C21IPUG': -2, 'C21IPGRD': -2, 'C21UGPRF': -2, 'C21ENPRF': -2, 'C21SZSET': -2}
# insert or update on table "institution_ipeds_info" violates foreign key constraint "fk_ipeds_scorecard"
# DETAIL:  Key (unitid, year)=(115287, 2021) is not present in table "institution_scorecard_info".
#
# Foreign key violation on row: {'UNITID': 117681, 'YEAR': 2021, 'INSTNM': 'Los Angeles Community College District Office', 'ADDR': '770 Wilshire Blvd', 'CITY': 'Los Angeles', 'STABBR': 'CA', 'ZIP': '90017', 'FIPS': 6, 'COUNTYCD': 6037, 'COUNTYNM': 'Los Angeles County', 'CBSA': 31080, 'CBSATYPE': 1, 'CSA': 348, 'LATITUDE': 34.048969, 'LONGITUD': -118.258047, 'C21BASIC': -2, 'C21IPUG': -2, 'C21IPGRD': -2, 'C21UGPRF': -2, 'C21ENPRF': -2, 'C21SZSET': -2}
# insert or update on table "institution_ipeds_info" violates foreign key constraint "fk_ipeds_scorecard"
# DETAIL:  Key (unitid, year)=(117681, 2021) is not present in table "institution_scorecard_info".
#
# Foreign key violation on row: {'UNITID': 117900, 'YEAR': 2021, 'INSTNM': 'Los Rios Community College District Office', 'ADDR': '1919 Spanos Ct', 'CITY': 'Sacramento', 'STABBR': 'CA', 'ZIP': '95825-3981', 'FIPS': 6, 'COUNTYCD': 6067, 'COUNTYNM': 'Sacramento County', 'CBSA': 40900, 'CBSATYPE': 1, 'CSA': 472, 'LATITUDE': 38.579859, 'LONGITUD': -121.417145, 'C21BASIC': -2, 'C21IPUG': -2, 'C21IPGRD': -2, 'C21UGPRF': -2, 'C21ENPRF': -2, 'C21SZSET': -2}
# insert or update on table "institution_ipeds_info" violates foreign key constraint "fk_ipeds_scorecard"
# DETAIL:  Key (unitid, year)=(117900, 2021) is not present in table "institution_scorecard_info".
#
# Foreign key violation on row: {'UNITID': 120023, 'YEAR': 2021, 'INSTNM': 'North Orange County Community College District', 'ADDR': '1830 W. Romneya Drive', 'CITY': 'Anaheim', 'STABBR': 'CA', 'ZIP': '92801-1819', 'FIPS': 6, 'COUNTYCD': 6059, 'COUNTYNM': 'Orange County', 'CBSA': 31080, 'CBSATYPE': 1, 'CSA': 348, 'LATITUDE': 33.849957, 'LONGITUD': -117.945559, 'C21BASIC': -2, 'C21IPUG': -2, 'C21IPGRD': -2, 'C21UGPRF': -2, 'C21ENPRF': -2, 'C21SZSET': -2}
# insert or update on table "institution_ipeds_info" violates foreign key constraint "fk_ipeds_scorecard"
# DETAIL:  Key (unitid, year)=(120023, 2021) is not present in table "institution_scorecard_info".
#
# Foreign key violation on row: {'UNITID': 121178, 'YEAR': 2021, 'INSTNM': 'Peralta Community College System Office', 'ADDR': '333 E Eighth St', 'CITY': 'Oakland', 'STABBR': 'CA', 'ZIP': '94606', 'FIPS': 6, 'COUNTYCD': 6001, 'COUNTYNM': 'Alameda County', 'CBSA': 41860, 'CBSATYPE': 1, 'CSA': 488, 'LATITUDE': 37.792667, 'LONGITUD': -122.260837, 'C21BASIC': -2, 'C21IPUG': -2, 'C21IPGRD': -2, 'C21UGPRF': -2, 'C21ENPRF': -2, 'C21SZSET': -2}
# insert or update on table "institution_ipeds_info" violates foreign key constraint "fk_ipeds_scorecard"
# DETAIL:  Key (unitid, year)=(121178, 2021) is not present in table "institution_scorecard_info".
#
# Foreign key violation on row: {'UNITID': 122320, 'YEAR': 2021, 'INSTNM': 'San Diego Community College District-District Office', 'ADDR': '3375 Camino del Rio South', 'CITY': 'San Diego', 'STABBR': 'CA', 'ZIP': '92108', 'FIPS': 6, 'COUNTYCD': 6073, 'COUNTYNM': 'San Diego County', 'CBSA': 41740, 'CBSATYPE': 1, 'CSA': -2, 'LATITUDE': 32.776275, 'LONGITUD': -117.120504, 'C21BASIC': -2, 'C21IPUG': -2, 'C21IPGRD': -2, 'C21UGPRF': -2, 'C21ENPRF': -2, 'C21SZSET': -2}
# insert or update on table "institution_ipeds_info" violates foreign key constraint "fk_ipeds_scorecard"
# DETAIL:  Key (unitid, year)=(122320, 2021) is not present in table "institution_scorecard_info".
#
# Foreign key violation on row: {'UNITID': 122737, 'YEAR': 2021, 'INSTNM': 'San Jose-Evergreen Community College District', 'ADDR': '40 South Market Street', 'CITY': 'San Jose', 'STABBR': 'CA', 'ZIP': '95113-1599', 'FIPS': 6, 'COUNTYCD': 6085, 'COUNTYNM': 'Santa Clara County', 'CBSA': 41940, 'CBSATYPE': 1, 'CSA': 488, 'LATITUDE': 37.334851, 'LONGITUD': -121.89118, 'C21BASIC': -2, 'C21IPUG': -2, 'C21IPGRD': -2, 'C21UGPRF': -2, 'C21ENPRF': -2, 'C21SZSET': -2}
# insert or update on table "institution_ipeds_info" violates foreign key constraint "fk_ipeds_scorecard"
# DETAIL:  Key (unitid, year)=(122737, 2021) is not present in table "institution_scorecard_info".
#
# Foreign key violation on row: {'UNITID': 122782, 'YEAR': 2021, 'INSTNM': 'San Mateo County Community College District Office', 'ADDR': '3401 CSM Drive', 'CITY': 'San Mateo', 'STABBR': 'CA', 'ZIP': '94402', 'FIPS': 6, 'COUNTYCD': 6081, 'COUNTYNM': 'San Mateo County', 'CBSA': 41860, 'CBSATYPE': 1, 'CSA': 488, 'LATITUDE': 37.531305, 'LONGITUD': -122.337627, 'C21BASIC': -2, 'C21IPUG': -2, 'C21IPGRD': -2, 'C21UGPRF': -2, 'C21ENPRF': -2, 'C21SZSET': -2}
# insert or update on table "institution_ipeds_info" violates foreign key constraint "fk_ipeds_scorecard"
# DETAIL:  Key (unitid, year)=(122782, 2021) is not present in table "institution_scorecard_info".
#
# Foreign key violation on row: {'UNITID': 123925, 'YEAR': 2021, 'INSTNM': 'State Center Community College District', 'ADDR': '1171 Fulton Street', 'CITY': 'Fresno', 'STABBR': 'CA', 'ZIP': '93721', 'FIPS': 6, 'COUNTYCD': 6019, 'COUNTYNM': 'Fresno County', 'CBSA': 23420, 'CBSATYPE': 1, 'CSA': 260, 'LATITUDE': 36.735642, 'LONGITUD': -119.792324, 'C21BASIC': -2, 'C21IPUG': -2, 'C21IPGRD': -2, 'C21UGPRF': -2, 'C21ENPRF': -2, 'C21SZSET': -2}
# insert or update on table "institution_ipeds_info" violates foreign key constraint "fk_ipeds_scorecard"
# DETAIL:  Key (unitid, year)=(123925, 2021) is not present in table "institution_scorecard_info".
#
# Foreign key violation on row: {'UNITID': 124557, 'YEAR': 2021, 'INSTNM': 'University of California-System Administration Central Office', 'ADDR': '1111 Franklin St', 'CITY': 'Oakland', 'STABBR': 'CA', 'ZIP': '94607-5200', 'FIPS': 6, 'COUNTYCD': 6001, 'COUNTYNM': 'Alameda County', 'CBSA': 41860, 'CBSATYPE': 1, 'CSA': 488, 'LATITUDE': 37.802222, 'LONGITUD': -122.27134, 'C21BASIC': -2, 'C21IPUG': -2, 'C21IPGRD': -2, 'C21UGPRF': -2, 'C21ENPRF': -2, 'C21SZSET': -2}
# insert or update on table "institution_ipeds_info" violates foreign key constraint "fk_ipeds_scorecard"
# DETAIL:  Key (unitid, year)=(124557, 2021) is not present in table "institution_scorecard_info".
#
# Foreign key violation on row: {'UNITID': 125019, 'YEAR': 2021, 'INSTNM': 'Ventura County Community College System Office', 'ADDR': '761 E. Daily Drive, Suite 200', 'CITY': 'Camarillo', 'STABBR': 'CA', 'ZIP': '93010', 'FIPS': 6, 'COUNTYCD': 6111, 'COUNTYNM': 'Ventura County', 'CBSA': 37100, 'CBSATYPE': 1, 'CSA': 348, 'LATITUDE': 34.219073, 'LONGITUD': -119.057951, 'C21BASIC': -2, 'C21IPUG': -2, 'C21IPGRD': -2, 'C21UGPRF': -2, 'C21ENPRF': -2, 'C21SZSET': -2}
# insert or update on table "institution_ipeds_info" violates foreign key constraint "fk_ipeds_scorecard"
# DETAIL:  Key (unitid, year)=(125019, 2021) is not present in table "institution_scorecard_info".
#
# Foreign key violation on row: {'UNITID': 125222, 'YEAR': 2021, 'INSTNM': 'West Valley Mission Community College District Office', 'ADDR': '14000 Fruitvale Ave', 'CITY': 'Saratoga', 'STABBR': 'CA', 'ZIP': '95070-5698', 'FIPS': 6, 'COUNTYCD': 6085, 'COUNTYNM': 'Santa Clara County', 'CBSA': 41940, 'CBSATYPE': 1, 'CSA': 488, 'LATITUDE': 37.26398, 'LONGITUD': -122.008324, 'C21BASIC': -2, 'C21IPUG': -2, 'C21IPGRD': -2, 'C21UGPRF': -2, 'C21ENPRF': -2, 'C21SZSET': -2}
# insert or update on table "institution_ipeds_info" violates foreign key constraint "fk_ipeds_scorecard"
# DETAIL:  Key (unitid, year)=(125222, 2021) is not present in table "institution_scorecard_info".
#
# Foreign key violation on row: {'UNITID': 126100, 'YEAR': 2021, 'INSTNM': 'Yosemite Community College District Office', 'ADDR': '2201 Blue Gum Ave', 'CITY': 'Modesto', 'STABBR': 'CA', 'ZIP': '95358', 'FIPS': 6, 'COUNTYCD': 6099, 'COUNTYNM': 'Stanislaus County', 'CBSA': 33700, 'CBSATYPE': 1, 'CSA': 488, 'LATITUDE': 37.66107, 'LONGITUD': -121.040246, 'C21BASIC': -2, 'C21IPUG': -2, 'C21IPGRD': -2, 'C21UGPRF': -2, 'C21ENPRF': -2, 'C21SZSET': -2}
# insert or update on table "institution_ipeds_info" violates foreign key constraint "fk_ipeds_scorecard"
# DETAIL:  Key (unitid, year)=(126100, 2021) is not present in table "institution_scorecard_info".
#
# Foreign key violation on row: {'UNITID': 128300, 'YEAR': 2021, 'INSTNM': 'University of Colorado System Office', 'ADDR': '1800 Grant St', 'CITY': 'Denver', 'STABBR': 'CO', 'ZIP': '80203-1187', 'FIPS': 8, 'COUNTYCD': 8031, 'COUNTYNM': 'Denver County', 'CBSA': 19740, 'CBSATYPE': 1, 'CSA': 216, 'LATITUDE': 39.74521, 'LONGITUD': -104.983277, 'C21BASIC': -2, 'C21IPUG': -2, 'C21IPGRD': -2, 'C21UGPRF': -2, 'C21ENPRF': -2, 'C21SZSET': -2}
# insert or update on table "institution_ipeds_info" violates foreign key constraint "fk_ipeds_scorecard"
# DETAIL:  Key (unitid, year)=(128300, 2021) is not present in table "institution_scorecard_info".
#
# Foreign key violation on row: {'UNITID': 130882, 'YEAR': 2021, 'INSTNM': 'Delaware Technical Community College-Central Office', 'ADDR': '1832 North Dupont Highway', 'CITY': 'Dover', 'STABBR': 'DE', 'ZIP': '19901', 'FIPS': 10, 'COUNTYCD': 10001, 'COUNTYNM': 'Kent County', 'CBSA': 20100, 'CBSATYPE': 1, 'CSA': 428, 'LATITUDE': 39.20109, 'LONGITUD': -75.5582, 'C21BASIC': -2, 'C21IPUG': -2, 'C21IPGRD': -2, 'C21UGPRF': -2, 'C21ENPRF': -2, 'C21SZSET': -2}
# insert or update on table "institution_ipeds_info" violates foreign key constraint "fk_ipeds_scorecard"
# DETAIL:  Key (unitid, year)=(130882, 2021) is not present in table "institution_scorecard_info".
#
# Foreign key violation on row: {'UNITID': 141963, 'YEAR': 2021, 'INSTNM': 'University of Hawaii System Office', 'ADDR': '2444 Dole St', 'CITY': 'Honolulu', 'STABBR': 'HI', 'ZIP': '96822-2399', 'FIPS': 15, 'COUNTYCD': 15003, 'COUNTYNM': 'Honolulu County', 'CBSA': 46520, 'CBSATYPE': 1, 'CSA': -2, 'LATITUDE': 21.297263, 'LONGITUD': -157.819849, 'C21BASIC': -2, 'C21IPUG': -2, 'C21IPGRD': -2, 'C21UGPRF': -2, 'C21ENPRF': -2, 'C21SZSET': -2}
# insert or update on table "institution_ipeds_info" violates foreign key constraint "fk_ipeds_scorecard"
# DETAIL:  Key (unitid, year)=(141963, 2021) is not present in table "institution_scorecard_info".
#
# Foreign key violation on row: {'UNITID': 144500, 'YEAR': 2021, 'INSTNM': 'City Colleges of Chicago-District Office', 'ADDR': '180 N. Wabash', 'CITY': 'Chicago', 'STABBR': 'IL', 'ZIP': '60601', 'FIPS': 17, 'COUNTYCD': 17031, 'COUNTYNM': 'Cook County', 'CBSA': 16980, 'CBSATYPE': 1, 'CSA': 176, 'LATITUDE': 41.885452, 'LONGITUD': -87.62671, 'C21BASIC': -2, 'C21IPUG': -2, 'C21IPGRD': -2, 'C21UGPRF': -2, 'C21ENPRF': -2, 'C21SZSET': -2}
# insert or update on table "institution_ipeds_info" violates foreign key constraint "fk_ipeds_scorecard"
# DETAIL:  Key (unitid, year)=(144500, 2021) is not present in table "institution_scorecard_info".
#
# Foreign key violation on row: {'UNITID': 144777, 'YEAR': 2021, 'INSTNM': 'DeVry University-Administrative Office', 'ADDR': '1200 E. Diehl Road', 'CITY': 'Naperville', 'STABBR': 'IL', 'ZIP': '60563', 'FIPS': 17, 'COUNTYCD': 17043, 'COUNTYNM': 'DuPage County', 'CBSA': 16980, 'CBSATYPE': 1, 'CSA': 176, 'LATITUDE': 41.799874, 'LONGITUD': -88.126334, 'C21BASIC': -2, 'C21IPUG': -2, 'C21IPGRD': -2, 'C21UGPRF': -2, 'C21ENPRF': -2, 'C21SZSET': -2}
# insert or update on table "institution_ipeds_info" violates foreign key constraint "fk_ipeds_scorecard"
# DETAIL:  Key (unitid, year)=(144777, 2021) is not present in table "institution_scorecard_info".
#
# Foreign key violation on row: {'UNITID': 149240, 'YEAR': 2021, 'INSTNM': 'Southern Illinois University-System Office', 'ADDR': '1400 Douglas Drive', 'CITY': 'Carbondale', 'STABBR': 'IL', 'ZIP': '62901-6801', 'FIPS': 17, 'COUNTYCD': 17077, 'COUNTYNM': 'Jackson County', 'CBSA': 16060, 'CBSATYPE': 1, 'CSA': -2, 'LATITUDE': 37.706473, 'LONGITUD': -89.232216, 'C21BASIC': -2, 'C21IPUG': -2, 'C21IPGRD': -2, 'C21UGPRF': -2, 'C21ENPRF': -2, 'C21SZSET': -2}
# insert or update on table "institution_ipeds_info" violates foreign key constraint "fk_ipeds_scorecard"
# DETAIL:  Key (unitid, year)=(149240, 2021) is not present in table "institution_scorecard_info".
#
# Foreign key violation on row: {'UNITID': 149587, 'YEAR': 2021, 'INSTNM': 'University of Illinois System Offices', 'ADDR': '108 Henry Administration Building, 506 S Wright Street', 'CITY': 'Urbana', 'STABBR': 'IL', 'ZIP': '61801', 'FIPS': 17, 'COUNTYCD': 17019, 'COUNTYNM': 'Champaign County', 'CBSA': 16580, 'CBSATYPE': 1, 'CSA': -2, 'LATITUDE': 40.108253, 'LONGITUD': -88.228234, 'C21BASIC': -2, 'C21IPUG': -2, 'C21IPGRD': -2, 'C21UGPRF': -2, 'C21ENPRF': -2, 'C21SZSET': -2}
# insert or update on table "institution_ipeds_info" violates foreign key constraint "fk_ipeds_scorecard"
# DETAIL:  Key (unitid, year)=(149587, 2021) is not present in table "institution_scorecard_info".
#
# Foreign key violation on row: {'UNITID': 154341, 'YEAR': 2021, 'INSTNM': 'La James International College-Iowa City', 'ADDR': '227 E Market-Brewery Sq', 'CITY': 'Iowa City', 'STABBR': 'IA', 'ZIP': '52245', 'FIPS': 19, 'COUNTYCD': 19103, 'COUNTYNM': 'Johnson County', 'CBSA': 26980, 'CBSATYPE': 1, 'CSA': 168, 'LATITUDE': 41.663433, 'LONGITUD': -91.532038, 'C21BASIC': -2, 'C21IPUG': -2, 'C21IPGRD': -2, 'C21UGPRF': -2, 'C21ENPRF': -2, 'C21SZSET': -2}
# insert or update on table "institution_ipeds_info" violates foreign key constraint "fk_ipeds_scorecard"
# DETAIL:  Key (unitid, year)=(154341, 2021) is not present in table "institution_scorecard_info".
#
# Foreign key violation on row: {'UNITID': 157854, 'YEAR': 2021, 'INSTNM': 'Kentucky Community and Technical College System', 'ADDR': '300 North Main Street', 'CITY': 'Versailles', 'STABBR': 'KY', 'ZIP': '40383-1245', 'FIPS': 21, 'COUNTYCD': 21239, 'COUNTYNM': 'Woodford County', 'CBSA': 30460, 'CBSATYPE': 1, 'CSA': 336, 'LATITUDE': 38.058771, 'LONGITUD': -84.72788, 'C21BASIC': -2, 'C21IPUG': -2, 'C21IPGRD': -2, 'C21UGPRF': -2, 'C21ENPRF': -2, 'C21SZSET': -2}
# insert or update on table "institution_ipeds_info" violates foreign key constraint "fk_ipeds_scorecard"
# DETAIL:  Key (unitid, year)=(157854, 2021) is not present in table "institution_scorecard_info".
#
# Foreign key violation on row: {'UNITID': 160533, 'YEAR': 2021, 'INSTNM': 'Southern University-Board and System', 'ADDR': 'JS Clark Admin Bldg 4th Floor', 'CITY': 'Baton Rouge', 'STABBR': 'LA', 'ZIP': '70813', 'FIPS': 22, 'COUNTYCD': 22033, 'COUNTYNM': 'East Baton Rouge Parish', 'CBSA': 12940, 'CBSATYPE': 1, 'CSA': -2, 'LATITUDE': 30.521517, 'LONGITUD': -91.196629, 'C21BASIC': -2, 'C21IPUG': -2, 'C21IPGRD': -2, 'C21UGPRF': -2, 'C21ENPRF': -2, 'C21SZSET': -2}
# insert or update on table "institution_ipeds_info" violates foreign key constraint "fk_ipeds_scorecard"
# DETAIL:  Key (unitid, year)=(160533, 2021) is not present in table "institution_scorecard_info".
#
# Foreign key violation on row: {'UNITID': 161280, 'YEAR': 2021, 'INSTNM': 'University of Maine-System Central Office', 'ADDR': '15 Estabrooke Drive', 'CITY': 'Orono', 'STABBR': 'ME', 'ZIP': '04469', 'FIPS': 23, 'COUNTYCD': 23019, 'COUNTYNM': 'Penobscot County', 'CBSA': 12620, 'CBSATYPE': 1, 'CSA': -2, 'LATITUDE': 44.896388, 'LONGITUD': -68.66988, 'C21BASIC': -2, 'C21IPUG': -2, 'C21IPGRD': -2, 'C21UGPRF': -2, 'C21ENPRF': -2, 'C21SZSET': -2}
# insert or update on table "institution_ipeds_info" violates foreign key constraint "fk_ipeds_scorecard"
# DETAIL:  Key (unitid, year)=(161280, 2021) is not present in table "institution_scorecard_info".
#
# Foreign key violation on row: {'UNITID': 164146, 'YEAR': 2021, 'INSTNM': 'University System of Maryland', 'ADDR': '701 E. Pratt St.', 'CITY': 'Baltimore', 'STABBR': 'MD', 'ZIP': '21201', 'FIPS': 24, 'COUNTYCD': 24510, 'COUNTYNM': 'Baltimore City', 'CBSA': 12580, 'CBSATYPE': 1, 'CSA': 548, 'LATITUDE': 39.286077, 'LONGITUD': -76.605479, 'C21BASIC': -2, 'C21IPUG': -2, 'C21IPGRD': -2, 'C21UGPRF': -2, 'C21ENPRF': -2, 'C21SZSET': -2}
# insert or update on table "institution_ipeds_info" violates foreign key constraint "fk_ipeds_scorecard"
# DETAIL:  Key (unitid, year)=(164146, 2021) is not present in table "institution_scorecard_info".
#
# Foreign key violation on row: {'UNITID': 166665, 'YEAR': 2021, 'INSTNM': 'University of Massachusetts-Central Office', 'ADDR': '1 Beacon Street', 'CITY': 'Boston', 'STABBR': 'MA', 'ZIP': '02108', 'FIPS': 25, 'COUNTYCD': 25025, 'COUNTYNM': 'Suffolk County', 'CBSA': 14460, 'CBSATYPE': 1, 'CSA': 148, 'LATITUDE': 42.35849, 'LONGITUD': -71.060761, 'C21BASIC': -2, 'C21IPUG': -2, 'C21IPGRD': -2, 'C21UGPRF': -2, 'C21ENPRF': -2, 'C21SZSET': -2}
# insert or update on table "institution_ipeds_info" violates foreign key constraint "fk_ipeds_scorecard"
# DETAIL:  Key (unitid, year)=(166665, 2021) is not present in table "institution_scorecard_info".
#
# Foreign key violation on row: {'UNITID': 175999, 'YEAR': 2021, 'INSTNM': 'Board of Trustees-Mississippi State Institutions of Higher Learning', 'ADDR': '3825 Ridgewood Rd', 'CITY': 'Jackson', 'STABBR': 'MS', 'ZIP': '39211', 'FIPS': 28, 'COUNTYCD': 28049, 'COUNTYNM': 'Hinds County', 'CBSA': 27140, 'CBSATYPE': 1, 'CSA': 298, 'LATITUDE': 32.338859, 'LONGITUD': -90.144689, 'C21BASIC': -2, 'C21IPUG': -2, 'C21IPGRD': -2, 'C21UGPRF': -2, 'C21ENPRF': -2, 'C21SZSET': -2}
# insert or update on table "institution_ipeds_info" violates foreign key constraint "fk_ipeds_scorecard"
# DETAIL:  Key (unitid, year)=(175999, 2021) is not present in table "institution_scorecard_info".
#
# Foreign key violation on row: {'UNITID': 178439, 'YEAR': 2021, 'INSTNM': 'University of Missouri-System Office', 'ADDR': '105 Jesse Hall', 'CITY': 'Columbia', 'STABBR': 'MO', 'ZIP': '65211', 'FIPS': 29, 'COUNTYCD': 29019, 'COUNTYNM': 'Boone County', 'CBSA': 17860, 'CBSATYPE': 1, 'CSA': 190, 'LATITUDE': 38.94531, 'LONGITUD': -92.328843, 'C21BASIC': -2, 'C21IPUG': -2, 'C21IPGRD': -2, 'C21UGPRF': -2, 'C21ENPRF': -2, 'C21SZSET': -2}
# insert or update on table "institution_ipeds_info" violates foreign key constraint "fk_ipeds_scorecard"
# DETAIL:  Key (unitid, year)=(178439, 2021) is not present in table "institution_scorecard_info".
#
# Foreign key violation on row: {'UNITID': 181747, 'YEAR': 2021, 'INSTNM': 'University of Nebraska-Central Administration System Office', 'ADDR': '3835 Holdrege St', 'CITY': 'Lincoln', 'STABBR': 'NE', 'ZIP': '68583-0743', 'FIPS': 31, 'COUNTYCD': 31109, 'COUNTYNM': 'Lancaster County', 'CBSA': 30700, 'CBSATYPE': 1, 'CSA': 339, 'LATITUDE': 40.827494, 'LONGITUD': -96.665203, 'C21BASIC': -2, 'C21IPUG': -2, 'C21IPGRD': -2, 'C21UGPRF': -2, 'C21ENPRF': -2, 'C21SZSET': -2}
# insert or update on table "institution_ipeds_info" violates foreign key constraint "fk_ipeds_scorecard"
# DETAIL:  Key (unitid, year)=(181747, 2021) is not present in table "institution_scorecard_info".
#
# Foreign key violation on row: {'UNITID': 182519, 'YEAR': 2021, 'INSTNM': 'Nevada System of Higher Education-System Office', 'ADDR': '2601 Enterprise Rd', 'CITY': 'Reno', 'STABBR': 'NV', 'ZIP': '89512', 'FIPS': 32, 'COUNTYCD': 32031, 'COUNTYNM': 'Washoe County', 'CBSA': 39900, 'CBSATYPE': 1, 'CSA': 456, 'LATITUDE': 39.551272, 'LONGITUD': -119.812301, 'C21BASIC': -2, 'C21IPUG': -2, 'C21IPGRD': -2, 'C21UGPRF': -2, 'C21ENPRF': -2, 'C21SZSET': -2}
# insert or update on table "institution_ipeds_info" violates foreign key constraint "fk_ipeds_scorecard"
# DETAIL:  Key (unitid, year)=(182519, 2021) is not present in table "institution_scorecard_info".
#
# Foreign key violation on row: {'UNITID': 183327, 'YEAR': 2021, 'INSTNM': 'University System of New Hampshire System Office', 'ADDR': '5 Chenell Drive, Suite 301', 'CITY': 'Concord', 'STABBR': 'NH', 'ZIP': '03301-8503', 'FIPS': 33, 'COUNTYCD': 33013, 'COUNTYNM': 'Merrimack County', 'CBSA': 18180, 'CBSATYPE': 2, 'CSA': 148, 'LATITUDE': 43.212833, 'LONGITUD': -71.494937, 'C21BASIC': -2, 'C21IPUG': -2, 'C21IPGRD': -2, 'C21UGPRF': -2, 'C21ENPRF': -2, 'C21SZSET': -2}
# insert or update on table "institution_ipeds_info" violates foreign key constraint "fk_ipeds_scorecard"
# DETAIL:  Key (unitid, year)=(183327, 2021) is not present in table "institution_scorecard_info".
#
# Foreign key violation on row: {'UNITID': 190035, 'YEAR': 2021, 'INSTNM': 'CUNY System Office', 'ADDR': '205 East 42nd Street', 'CITY': 'New York', 'STABBR': 'NY', 'ZIP': '10017', 'FIPS': 36, 'COUNTYCD': 36061, 'COUNTYNM': 'New York County', 'CBSA': 35620, 'CBSATYPE': 1, 'CSA': 408, 'LATITUDE': 40.750845, 'LONGITUD': -73.973639, 'C21BASIC': -2, 'C21IPUG': -2, 'C21IPGRD': -2, 'C21UGPRF': -2, 'C21ENPRF': -2, 'C21SZSET': -2}
# insert or update on table "institution_ipeds_info" violates foreign key constraint "fk_ipeds_scorecard"
# DETAIL:  Key (unitid, year)=(190035, 2021) is not present in table "institution_scorecard_info".
#
# Foreign key violation on row: {'UNITID': 195827, 'YEAR': 2021, 'INSTNM': 'SUNY-System Office', 'ADDR': 'H. Carl McCall Building, 353 Broadway', 'CITY': 'Albany', 'STABBR': 'NY', 'ZIP': '12246', 'FIPS': 36, 'COUNTYCD': 36001, 'COUNTYNM': 'Albany County', 'CBSA': 10580, 'CBSATYPE': 1, 'CSA': 104, 'LATITUDE': 42.648047, 'LONGITUD': -73.749494, 'C21BASIC': -2, 'C21IPUG': -2, 'C21IPGRD': -2, 'C21UGPRF': -2, 'C21ENPRF': -2, 'C21SZSET': -2}
# insert or update on table "institution_ipeds_info" violates foreign key constraint "fk_ipeds_scorecard"
# DETAIL:  Key (unitid, year)=(195827, 2021) is not present in table "institution_scorecard_info".
#
# Foreign key violation on row: {'UNITID': 199175, 'YEAR': 2021, 'INSTNM': 'University of North Carolina System', 'ADDR': '910 Raleigh Rd', 'CITY': 'Chapel Hill', 'STABBR': 'NC', 'ZIP': '27514', 'FIPS': 37, 'COUNTYCD': 37135, 'COUNTYNM': 'Orange County', 'CBSA': 20500, 'CBSATYPE': 1, 'CSA': 450, 'LATITUDE': 35.908783, 'LONGITUD': -79.029687, 'C21BASIC': -2, 'C21IPUG': -2, 'C21IPGRD': -2, 'C21UGPRF': -2, 'C21ENPRF': -2, 'C21SZSET': -2}
# insert or update on table "institution_ipeds_info" violates foreign key constraint "fk_ipeds_scorecard"
# DETAIL:  Key (unitid, year)=(199175, 2021) is not present in table "institution_scorecard_info".
#
# Foreign key violation on row: {'UNITID': 213552, 'YEAR': 2021, 'INSTNM': 'Levittown Beauty Academy', 'ADDR': 'Vermillion Square - 8919 New Falls Road', 'CITY': 'Levittown', 'STABBR': 'PA', 'ZIP': '19054', 'FIPS': 42, 'COUNTYCD': 42017, 'COUNTYNM': 'Bucks County', 'CBSA': 37980, 'CBSATYPE': 1, 'CSA': 428, 'LATITUDE': 40.177232, 'LONGITUD': -74.829013, 'C21BASIC': -2, 'C21IPUG': -2, 'C21IPGRD': -2, 'C21UGPRF': -2, 'C21ENPRF': -2, 'C21SZSET': -2}
# insert or update on table "institution_ipeds_info" violates foreign key constraint "fk_ipeds_scorecard"
# DETAIL:  Key (unitid, year)=(213552, 2021) is not present in table "institution_scorecard_info".
#
# Foreign key violation on row: {'UNITID': 214661, 'YEAR': 2021, 'INSTNM': 'Pennsylvania State System of Higher Education-Central Office', 'ADDR': '2986 N 2nd St Dixon Univ Center', 'CITY': 'Harrisburg', 'STABBR': 'PA', 'ZIP': '17110', 'FIPS': 42, 'COUNTYCD': 42043, 'COUNTYNM': 'Dauphin County', 'CBSA': 25420, 'CBSATYPE': 1, 'CSA': 276, 'LATITUDE': 40.294887, 'LONGITUD': -76.904363, 'C21BASIC': -2, 'C21IPUG': -2, 'C21IPGRD': -2, 'C21UGPRF': -2, 'C21ENPRF': -2, 'C21SZSET': -2}
# insert or update on table "institution_ipeds_info" violates foreign key constraint "fk_ipeds_scorecard"
# DETAIL:  Key (unitid, year)=(214661, 2021) is not present in table "institution_scorecard_info".
#
# Foreign key violation on row: {'UNITID': 222497, 'YEAR': 2021, 'INSTNM': 'Alamo Community College District Central Office', 'ADDR': '2222 N. Alamo St.', 'CITY': 'San Antonio', 'STABBR': 'TX', 'ZIP': '78215', 'FIPS': 48, 'COUNTYCD': 48029, 'COUNTYNM': 'Bexar County', 'CBSA': 41700, 'CBSATYPE': 1, 'CSA': 484, 'LATITUDE': 29.445773, 'LONGITUD': -98.474082, 'C21BASIC': -2, 'C21IPUG': -2, 'C21IPGRD': -2, 'C21UGPRF': -2, 'C21ENPRF': -2, 'C21SZSET': -2}
# insert or update on table "institution_ipeds_info" violates foreign key constraint "fk_ipeds_scorecard"
# DETAIL:  Key (unitid, year)=(222497, 2021) is not present in table "institution_scorecard_info".
#
# Foreign key violation on row: {'UNITID': 228732, 'YEAR': 2021, 'INSTNM': 'Texas A & M University-System Office', 'ADDR': '301 Tarrow', 'CITY': 'College Station', 'STABBR': 'TX', 'ZIP': '77840-7896', 'FIPS': 48, 'COUNTYCD': 48041, 'COUNTYNM': 'Brazos County', 'CBSA': 17780, 'CBSATYPE': 1, 'CSA': -2, 'LATITUDE': 30.636846, 'LONGITUD': -96.327705, 'C21BASIC': -2, 'C21IPUG': -2, 'C21IPGRD': -2, 'C21UGPRF': -2, 'C21ENPRF': -2, 'C21SZSET': -2}
# insert or update on table "institution_ipeds_info" violates foreign key constraint "fk_ipeds_scorecard"
# DETAIL:  Key (unitid, year)=(228732, 2021) is not present in table "institution_scorecard_info".
#
# Foreign key violation on row: {'UNITID': 229090, 'YEAR': 2021, 'INSTNM': 'The University of Texas System Office', 'ADDR': '210 W. 7th St', 'CITY': 'Austin', 'STABBR': 'TX', 'ZIP': '78701-2982', 'FIPS': 48, 'COUNTYCD': 48453, 'COUNTYNM': 'Travis County', 'CBSA': 12420, 'CBSATYPE': 1, 'CSA': -2, 'LATITUDE': 30.269742, 'LONGITUD': -97.744284, 'C21BASIC': -2, 'C21IPUG': -2, 'C21IPGRD': -2, 'C21UGPRF': -2, 'C21ENPRF': -2, 'C21SZSET': -2}
# insert or update on table "institution_ipeds_info" violates foreign key constraint "fk_ipeds_scorecard"
# DETAIL:  Key (unitid, year)=(229090, 2021) is not present in table "institution_scorecard_info".
#
# Foreign key violation on row: {'UNITID': 229407, 'YEAR': 2021, 'INSTNM': 'University of Houston-System Administration', 'ADDR': '212 Ezekiel Cullen Building', 'CITY': 'Houston', 'STABBR': 'TX', 'ZIP': '77204-2018', 'FIPS': 48, 'COUNTYCD': 48201, 'COUNTYNM': 'Harris County', 'CBSA': 26420, 'CBSATYPE': 1, 'CSA': 288, 'LATITUDE': 29.720393, 'LONGITUD': -95.343537, 'C21BASIC': -2, 'C21IPUG': -2, 'C21IPGRD': -2, 'C21UGPRF': -2, 'C21ENPRF': -2, 'C21SZSET': -2}
# insert or update on table "institution_ipeds_info" violates foreign key constraint "fk_ipeds_scorecard"
# DETAIL:  Key (unitid, year)=(229407, 2021) is not present in table "institution_scorecard_info".
#
# Foreign key violation on row: {'UNITID': 231156, 'YEAR': 2021, 'INSTNM': 'Vermont State Colleges-Office of the Chancellor', 'ADDR': '575 Stone Cutters Way, Suite 1', 'CITY': 'Montpelier', 'STABBR': 'VT', 'ZIP': '05602', 'FIPS': 50, 'COUNTYCD': 50023, 'COUNTYNM': 'Washington County', 'CBSA': 12740, 'CBSATYPE': 2, 'CSA': 162, 'LATITUDE': 44.25425, 'LONGITUD': -72.572581, 'C21BASIC': -2, 'C21IPUG': -2, 'C21IPGRD': -2, 'C21UGPRF': -2, 'C21ENPRF': -2, 'C21SZSET': -2}
# insert or update on table "institution_ipeds_info" violates foreign key constraint "fk_ipeds_scorecard"
# DETAIL:  Key (unitid, year)=(231156, 2021) is not present in table "institution_scorecard_info".
#
# Foreign key violation on row: {'UNITID': 240435, 'YEAR': 2021, 'INSTNM': 'University of Wisconsin-System Administration', 'ADDR': '1220 Linden Dr', 'CITY': 'Madison', 'STABBR': 'WI', 'ZIP': '53706', 'FIPS': 55, 'COUNTYCD': 55025, 'COUNTYNM': 'Dane County', 'CBSA': 31540, 'CBSATYPE': 1, 'CSA': 357, 'LATITUDE': 43.075674, 'LONGITUD': -89.406804, 'C21BASIC': -2, 'C21IPUG': -2, 'C21IPGRD': -2, 'C21UGPRF': -2, 'C21ENPRF': -2, 'C21SZSET': -2}
# insert or update on table "institution_ipeds_info" violates foreign key constraint "fk_ipeds_scorecard"
# DETAIL:  Key (unitid, year)=(240435, 2021) is not present in table "institution_scorecard_info".
#
# Foreign key violation on row: {'UNITID': 242060, 'YEAR': 2021, 'INSTNM': 'Sistema Universitario Ana G. Mendez', 'ADDR': 'Universidad Ana G. Mendez, 1399 Ave Ana G. Mendez', 'CITY': 'Rio Piedras', 'STABBR': 'PR', 'ZIP': '00928-1345', 'FIPS': 72, 'COUNTYCD': 72127, 'COUNTYNM': 'San Juan Municipio', 'CBSA': 41980, 'CBSATYPE': 1, 'CSA': 490, 'LATITUDE': 18.387204, 'LONGITUD': -66.061653, 'C21BASIC': -2, 'C21IPUG': -2, 'C21IPGRD': -2, 'C21UGPRF': -2, 'C21ENPRF': -2, 'C21SZSET': -2}
# insert or update on table "institution_ipeds_info" violates foreign key constraint "fk_ipeds_scorecard"
# DETAIL:  Key (unitid, year)=(242060, 2021) is not present in table "institution_scorecard_info".
#
# Foreign key violation on row: {'UNITID': 242671, 'YEAR': 2021, 'INSTNM': 'Inter American University of Puerto Rico-Central Office', 'ADDR': 'Urb Jardines Metropolitanos Calle Galileo Final', 'CITY': 'San Juan', 'STABBR': 'PR', 'ZIP': '00928', 'FIPS': 72, 'COUNTYCD': 72127, 'COUNTYNM': 'San Juan Municipio', 'CBSA': 41980, 'CBSATYPE': 1, 'CSA': 490, 'LATITUDE': 18.403964, 'LONGITUD': -66.069533, 'C21BASIC': -2, 'C21IPUG': -2, 'C21IPGRD': -2, 'C21UGPRF': -2, 'C21ENPRF': -2, 'C21SZSET': -2}
# insert or update on table "institution_ipeds_info" violates foreign key constraint "fk_ipeds_scorecard"
# DETAIL:  Key (unitid, year)=(242671, 2021) is not present in table "institution_scorecard_info".
#
# Foreign key violation on row: {'UNITID': 243160, 'YEAR': 2021, 'INSTNM': 'University of Puerto Rico-Central Administration', 'ADDR': 'Carr #1, Km 12.9 Terrenos Estacion Exp.  Agricola', 'CITY': 'San Juan', 'STABBR': 'PR', 'ZIP': '00936-4984', 'FIPS': 72, 'COUNTYCD': 72127, 'COUNTYNM': 'San Juan Municipio', 'CBSA': 41980, 'CBSATYPE': 1, 'CSA': 490, 'LATITUDE': 18.38959, 'LONGITUD': -66.056329, 'C21BASIC': -2, 'C21IPUG': -2, 'C21IPGRD': -2, 'C21UGPRF': -2, 'C21ENPRF': -2, 'C21SZSET': -2}
# insert or update on table "institution_ipeds_info" violates foreign key constraint "fk_ipeds_scorecard"
# DETAIL:  Key (unitid, year)=(243160, 2021) is not present in table "institution_scorecard_info".
#
# Foreign key violation on row: {'UNITID': 247083, 'YEAR': 2021, 'INSTNM': 'University of Louisiana-System Administration', 'ADDR': 'Claiborne Building, 1201 N. 3rd St., Suite 7-300', 'CITY': 'Baton Rouge', 'STABBR': 'LA', 'ZIP': '70802', 'FIPS': 22, 'COUNTYCD': 22033, 'COUNTYNM': 'East Baton Rouge Parish', 'CBSA': 12940, 'CBSATYPE': 1, 'CSA': -2, 'LATITUDE': 30.459815, 'LONGITUD': -91.188679, 'C21BASIC': -2, 'C21IPUG': -2, 'C21IPGRD': -2, 'C21UGPRF': -2, 'C21ENPRF': -2, 'C21SZSET': -2}
# insert or update on table "institution_ipeds_info" violates foreign key constraint "fk_ipeds_scorecard"
# DETAIL:  Key (unitid, year)=(247083, 2021) is not present in table "institution_scorecard_info".
#
# Foreign key violation on row: {'UNITID': 247737, 'YEAR': 2021, 'INSTNM': 'Mississippi Community College Board', 'ADDR': '3825 Ridgewood Rd', 'CITY': 'Jackson', 'STABBR': 'MS', 'ZIP': '39211', 'FIPS': 28, 'COUNTYCD': 28049, 'COUNTYNM': 'Hinds County', 'CBSA': 27140, 'CBSATYPE': 1, 'CSA': 298, 'LATITUDE': 32.338859, 'LONGITUD': -90.144689, 'C21BASIC': -2, 'C21IPUG': -2, 'C21IPGRD': -2, 'C21UGPRF': -2, 'C21ENPRF': -2, 'C21SZSET': -2}
# insert or update on table "institution_ipeds_info" violates foreign key constraint "fk_ipeds_scorecard"
# DETAIL:  Key (unitid, year)=(247737, 2021) is not present in table "institution_scorecard_info".
#
# Foreign key violation on row: {'UNITID': 374990, 'YEAR': 2021, 'INSTNM': 'Continental School of Beauty Culture-Olean', 'ADDR': '517 N Barry St', 'CITY': 'Olean', 'STABBR': 'NY', 'ZIP': '14760', 'FIPS': 36, 'COUNTYCD': 36009, 'COUNTYNM': 'Cattaraugus County', 'CBSA': 36460, 'CBSATYPE': 2, 'CSA': 160, 'LATITUDE': 42.084487, 'LONGITUD': -78.428158, 'C21BASIC': -2, 'C21IPUG': -2, 'C21IPGRD': -2, 'C21UGPRF': -2, 'C21ENPRF': -2, 'C21SZSET': -2}
# insert or update on table "institution_ipeds_info" violates foreign key constraint "fk_ipeds_scorecard"
# DETAIL:  Key (unitid, year)=(374990, 2021) is not present in table "institution_scorecard_info".
#
# Foreign key violation on row: {'UNITID': 391546, 'YEAR': 2021, 'INSTNM': 'ASM Beauty World Academy', 'ADDR': '6672 & 6674 Stirling Road', 'CITY': 'Hollywood', 'STABBR': 'FL', 'ZIP': '33024', 'FIPS': 12, 'COUNTYCD': 12011, 'COUNTYNM': 'Broward County', 'CBSA': 33100, 'CBSATYPE': 1, 'CSA': 370, 'LATITUDE': 26.045461, 'LONGITUD': -80.222145, 'C21BASIC': -2, 'C21IPUG': -2, 'C21IPGRD': -2, 'C21UGPRF': -2, 'C21ENPRF': -2, 'C21SZSET': -2}
# insert or update on table "institution_ipeds_info" violates foreign key constraint "fk_ipeds_scorecard"
# DETAIL:  Key (unitid, year)=(391546, 2021) is not present in table "institution_scorecard_info".
#
# Foreign key violation on row: {'UNITID': 402776, 'YEAR': 2021, 'INSTNM': 'Southwest University of Visual Arts-Albuquerque', 'ADDR': ' ', 'CITY': 'Albuquerque', 'STABBR': 'NM', 'ZIP': '87102', 'FIPS': 35, 'COUNTYCD': 35001, 'COUNTYNM': 'Bernalillo County', 'CBSA': 10740, 'CBSATYPE': 1, 'CSA': 106, 'LATITUDE': 35.088818, 'LONGITUD': -106.589352, 'C21BASIC': -2, 'C21IPUG': -2, 'C21IPGRD': -2, 'C21UGPRF': -2, 'C21ENPRF': -2, 'C21SZSET': -2}
# insert or update on table "institution_ipeds_info" violates foreign key constraint "fk_ipeds_scorecard"
# DETAIL:  Key (unitid, year)=(402776, 2021) is not present in table "institution_scorecard_info".
#
# Foreign key violation on row: {'UNITID': 404480, 'YEAR': 2021, 'INSTNM': 'University System of Maryland-Research Centers', 'ADDR': '701 E. Pratt St.', 'CITY': 'Baltimore', 'STABBR': 'MD', 'ZIP': '21201', 'FIPS': 24, 'COUNTYCD': 24510, 'COUNTYNM': 'Baltimore City', 'CBSA': 12580, 'CBSATYPE': 1, 'CSA': 548, 'LATITUDE': 39.286077, 'LONGITUD': -76.605479, 'C21BASIC': -2, 'C21IPUG': -2, 'C21IPGRD': -2, 'C21UGPRF': -2, 'C21ENPRF': -2, 'C21SZSET': -2}
# insert or update on table "institution_ipeds_info" violates foreign key constraint "fk_ipeds_scorecard"
# DETAIL:  Key (unitid, year)=(404480, 2021) is not present in table "institution_scorecard_info".
#
# Foreign key violation on row: {'UNITID': 409379, 'YEAR': 2021, 'INSTNM': 'Tennessee Board of Regents', 'ADDR': '1 Bridgestone Park', 'CITY': 'Nashville', 'STABBR': 'TN', 'ZIP': '37214', 'FIPS': 47, 'COUNTYCD': 47037, 'COUNTYNM': 'Davidson County', 'CBSA': 34980, 'CBSATYPE': 1, 'CSA': 400, 'LATITUDE': 36.167183, 'LONGITUD': -86.690409, 'C21BASIC': -2, 'C21IPUG': -2, 'C21IPGRD': -2, 'C21UGPRF': -2, 'C21ENPRF': -2, 'C21SZSET': -2}
# insert or update on table "institution_ipeds_info" violates foreign key constraint "fk_ipeds_scorecard"
# DETAIL:  Key (unitid, year)=(409379, 2021) is not present in table "institution_scorecard_info".
#
# Foreign key violation on row: {'UNITID': 417053, 'YEAR': 2021, 'INSTNM': 'Cedars Sinai Medical Center', 'ADDR': '8700 Beverly Boulevard', 'CITY': 'Los Angeles', 'STABBR': 'CA', 'ZIP': '90048-0000', 'FIPS': 6, 'COUNTYCD': 6037, 'COUNTYNM': 'Los Angeles County', 'CBSA': 31080, 'CBSATYPE': 1, 'CSA': 348, 'LATITUDE': 34.075598, 'LONGITUD': -118.380175, 'C21BASIC': -2, 'C21IPUG': -2, 'C21IPGRD': -2, 'C21UGPRF': -2, 'C21ENPRF': -2, 'C21SZSET': -2}
# insert or update on table "institution_ipeds_info" violates foreign key constraint "fk_ipeds_scorecard"
# DETAIL:  Key (unitid, year)=(417053, 2021) is not present in table "institution_scorecard_info".
#
# Foreign key violation on row: {'UNITID': 420802, 'YEAR': 2021, 'INSTNM': 'Arizona Board of Regents', 'ADDR': '2700 N Central Ave, Suite 400', 'CITY': 'Phoenix', 'STABBR': 'AZ', 'ZIP': '85004', 'FIPS': 4, 'COUNTYCD': 4013, 'COUNTYNM': 'Maricopa County', 'CBSA': 38060, 'CBSATYPE': 1, 'CSA': 429, 'LATITUDE': 33.478133, 'LONGITUD': -112.074267, 'C21BASIC': -2, 'C21IPUG': -2, 'C21IPGRD': -2, 'C21UGPRF': -2, 'C21ENPRF': -2, 'C21SZSET': -2}
# insert or update on table "institution_ipeds_info" violates foreign key constraint "fk_ipeds_scorecard"
# DETAIL:  Key (unitid, year)=(420802, 2021) is not present in table "institution_scorecard_info".
#
# Foreign key violation on row: {'UNITID': 428426, 'YEAR': 2021, 'INSTNM': 'San Bernardino Community College District', 'ADDR': '550 E. Hospitality Lane, Suite 200', 'CITY': 'San Bernardino', 'STABBR': 'CA', 'ZIP': '92408', 'FIPS': 6, 'COUNTYCD': 6071, 'COUNTYNM': 'San Bernardino County', 'CBSA': 40140, 'CBSATYPE': 1, 'CSA': 348, 'LATITUDE': 34.067005, 'LONGITUD': -117.273664, 'C21BASIC': -2, 'C21IPUG': -2, 'C21IPGRD': -2, 'C21UGPRF': -2, 'C21ENPRF': -2, 'C21SZSET': -2}
# insert or update on table "institution_ipeds_info" violates foreign key constraint "fk_ipeds_scorecard"
# DETAIL:  Key (unitid, year)=(428426, 2021) is not present in table "institution_scorecard_info".
#
# Foreign key violation on row: {'UNITID': 428453, 'YEAR': 2021, 'INSTNM': 'Minnesota State Colleges and Universities System Office', 'ADDR': '30 East 7TH ST', 'CITY': 'ST PAUL', 'STABBR': 'MN', 'ZIP': '55101', 'FIPS': 27, 'COUNTYCD': 27123, 'COUNTYNM': 'Ramsey County', 'CBSA': 33460, 'CBSATYPE': 1, 'CSA': 378, 'LATITUDE': 44.94796, 'LONGITUD': -93.09568, 'C21BASIC': -2, 'C21IPUG': -2, 'C21IPGRD': -2, 'C21UGPRF': -2, 'C21ENPRF': -2, 'C21SZSET': -2}
# insert or update on table "institution_ipeds_info" violates foreign key constraint "fk_ipeds_scorecard"
# DETAIL:  Key (unitid, year)=(428453, 2021) is not present in table "institution_scorecard_info".
#
# Foreign key violation on row: {'UNITID': 430218, 'YEAR': 2021, 'INSTNM': 'Empire Beauty School-Bordentown', 'ADDR': '610 Rt 206', 'CITY': 'Bordentown', 'STABBR': 'NJ', 'ZIP': '08505', 'FIPS': 34, 'COUNTYCD': 34005, 'COUNTYNM': 'Burlington County', 'CBSA': 37980, 'CBSATYPE': 1, 'CSA': 428, 'LATITUDE': 40.173971, 'LONGITUD': -74.702495, 'C21BASIC': -2, 'C21IPUG': -2, 'C21IPGRD': -2, 'C21UGPRF': -2, 'C21ENPRF': -2, 'C21SZSET': -2}
# insert or update on table "institution_ipeds_info" violates foreign key constraint "fk_ipeds_scorecard"
# DETAIL:  Key (unitid, year)=(430218, 2021) is not present in table "institution_scorecard_info".
#
# Foreign key violation on row: {'UNITID': 432144, 'YEAR': 2021, 'INSTNM': 'South Orange County Community College District', 'ADDR': '28000 Marguerite Pky', 'CITY': 'Mission Viejo', 'STABBR': 'CA', 'ZIP': '92692-6399', 'FIPS': 6, 'COUNTYCD': 6059, 'COUNTYNM': 'Orange County', 'CBSA': 31080, 'CBSATYPE': 1, 'CSA': 348, 'LATITUDE': 33.553346, 'LONGITUD': -117.665584, 'C21BASIC': -2, 'C21IPUG': -2, 'C21IPGRD': -2, 'C21UGPRF': -2, 'C21ENPRF': -2, 'C21SZSET': -2}
# insert or update on table "institution_ipeds_info" violates foreign key constraint "fk_ipeds_scorecard"
# DETAIL:  Key (unitid, year)=(432144, 2021) is not present in table "institution_scorecard_info".
#
# Foreign key violation on row: {'UNITID': 438665, 'YEAR': 2021, 'INSTNM': 'Rancho Santiago Community College District Office', 'ADDR': '2323 N Broadway', 'CITY': 'Santa Ana', 'STABBR': 'CA', 'ZIP': '92706-1640', 'FIPS': 6, 'COUNTYCD': 6059, 'COUNTYNM': 'Orange County', 'CBSA': 31080, 'CBSATYPE': 1, 'CSA': 348, 'LATITUDE': 33.767331, 'LONGITUD': -117.868261, 'C21BASIC': -2, 'C21IPUG': -2, 'C21IPGRD': -2, 'C21UGPRF': -2, 'C21ENPRF': -2, 'C21SZSET': -2}
# insert or update on table "institution_ipeds_info" violates foreign key constraint "fk_ipeds_scorecard"
# DETAIL:  Key (unitid, year)=(438665, 2021) is not present in table "institution_scorecard_info".
#
# Foreign key violation on row: {'UNITID': 438869, 'YEAR': 2021, 'INSTNM': 'Remington College-Little Rock Campus', 'ADDR': '10600 Colonel Glenn Rd, Suite 100', 'CITY': 'Little Rock', 'STABBR': 'AR', 'ZIP': '72204', 'FIPS': 5, 'COUNTYCD': 5119, 'COUNTYNM': 'Pulaski County', 'CBSA': 30780, 'CBSATYPE': 1, 'CSA': 340, 'LATITUDE': 34.71308, 'LONGITUD': -92.393771, 'C21BASIC': -2, 'C21IPUG': -2, 'C21IPGRD': -2, 'C21UGPRF': -2, 'C21ENPRF': -2, 'C21SZSET': -2}
# insert or update on table "institution_ipeds_info" violates foreign key constraint "fk_ipeds_scorecard"
# DETAIL:  Key (unitid, year)=(438869, 2021) is not present in table "institution_scorecard_info".
#
# Foreign key violation on row: {'UNITID': 439154, 'YEAR': 2021, 'INSTNM': 'Texas Tech University System Administration', 'ADDR': '1508 Knoxville Avenue', 'CITY': 'Lubbock', 'STABBR': 'TX', 'ZIP': '79409-2013', 'FIPS': 48, 'COUNTYCD': 48303, 'COUNTYNM': 'Lubbock County', 'CBSA': 31180, 'CBSATYPE': 1, 'CSA': 352, 'LATITUDE': 33.581169, 'LONGITUD': -101.892826, 'C21BASIC': -2, 'C21IPUG': -2, 'C21IPGRD': -2, 'C21UGPRF': -2, 'C21ENPRF': -2, 'C21SZSET': -2}
# insert or update on table "institution_ipeds_info" violates foreign key constraint "fk_ipeds_scorecard"
# DETAIL:  Key (unitid, year)=(439154, 2021) is not present in table "institution_scorecard_info".
#
# Foreign key violation on row: {'UNITID': 440138, 'YEAR': 2021, 'INSTNM': 'Antioch University-System Administration', 'ADDR': '900 Dayton Street', 'CITY': 'Yellow Springs', 'STABBR': 'OH', 'ZIP': '45387', 'FIPS': 39, 'COUNTYCD': 39057, 'COUNTYNM': 'Greene County', 'CBSA': 19430, 'CBSATYPE': 1, 'CSA': 212, 'LATITUDE': 39.80321, 'LONGITUD': -83.908684, 'C21BASIC': -2, 'C21IPUG': -2, 'C21IPGRD': -2, 'C21UGPRF': -2, 'C21ENPRF': -2, 'C21SZSET': -2}
# insert or update on table "institution_ipeds_info" violates foreign key constraint "fk_ipeds_scorecard"
# DETAIL:  Key (unitid, year)=(440138, 2021) is not present in table "institution_scorecard_info".
#
# Foreign key violation on row: {'UNITID': 443368, 'YEAR': 2021, 'INSTNM': 'Illinois Eastern Community College-System Office', 'ADDR': '233 E Chestnut Street', 'CITY': 'Olney', 'STABBR': 'IL', 'ZIP': '62450', 'FIPS': 17, 'COUNTYCD': 17159, 'COUNTYNM': 'Richland County', 'CBSA': -2, 'CBSATYPE': -2, 'CSA': -2, 'LATITUDE': 38.729684, 'LONGITUD': -88.081976, 'C21BASIC': -2, 'C21IPUG': -2, 'C21IPGRD': -2, 'C21UGPRF': -2, 'C21ENPRF': -2, 'C21SZSET': -2}
# insert or update on table "institution_ipeds_info" violates foreign key constraint "fk_ipeds_scorecard"
# DETAIL:  Key (unitid, year)=(443368, 2021) is not present in table "institution_scorecard_info".
#
# ...
# DETAIL:  Key (unitid, year)=(497055, 2021) is not present in table "institution_scorecard_info".
#
# Foreign key violation on row: {'UNITID': 497064, 'YEAR': 2021, 'INSTNM': 'Moody Bible Institute -', 'ADDR': '6719 East Rutter Avenue #68', 'CITY': 'Spokane', 'STABBR': 'WA', 'ZIP': '99212-1451', 'FIPS': 53, 'COUNTYCD': 53063, 'COUNTYNM': 'Spokane County', 'CBSA': 44060, 'CBSATYPE': 1, 'CSA': 518, 'LATITUDE': 47.682052, 'LONGITUD': -117.313336, 'C21BASIC': -2, 'C21IPUG': -2, 'C21IPGRD': -2, 'C21UGPRF': -2, 'C21ENPRF': -2, 'C21SZSET': -2}
# insert or update on table "institution_ipeds_info" violates foreign key constraint "fk_ipeds_scorecard"
# DETAIL:  Key (unitid, year)=(497064, 2021) is not present in table "institution_scorecard_info".
#
# Foreign key violation on row: {'UNITID': 497073, 'YEAR': 2021, 'INSTNM': 'Ogle School Hair Skin Nails-Willowbrook', 'ADDR': '12974-A Willow Chase Drive', 'CITY': 'Houston', 'STABBR': 'TX', 'ZIP': '77070-5656', 'FIPS': 48, 'COUNTYCD': 48201, 'COUNTYNM': 'Harris County', 'CBSA': 26420, 'CBSATYPE': 1, 'CSA': 288, 'LATITUDE': 29.961825, 'LONGITUD': -95.550032, 'C21BASIC': -2, 'C21IPUG': -2, 'C21IPGRD': -2, 'C21UGPRF': -2, 'C21ENPRF': -2, 'C21SZSET': -2}
# insert or update on table "institution_ipeds_info" violates foreign key constraint "fk_ipeds_scorecard"
# DETAIL:  Key (unitid, year)=(497073, 2021) is not present in table "institution_scorecard_info".
#
# Foreign key violation on row: {'UNITID': 497091, 'YEAR': 2021, 'INSTNM': 'Bell-Brown Medical Institute', 'ADDR': '470 Howdershell Road', 'CITY': 'Florissant', 'STABBR': 'MO', 'ZIP': '63031-6419', 'FIPS': 29, 'COUNTYCD': 29189, 'COUNTYNM': 'St. Louis County', 'CBSA': 41180, 'CBSATYPE': 1, 'CSA': 476, 'LATITUDE': 38.804332, 'LONGITUD': -90.361452, 'C21BASIC': -2, 'C21IPUG': -2, 'C21IPGRD': -2, 'C21UGPRF': -2, 'C21ENPRF': -2, 'C21SZSET': -2}
# insert or update on table "institution_ipeds_info" violates foreign key constraint "fk_ipeds_scorecard"
# DETAIL:  Key (unitid, year)=(497091, 2021) is not present in table "institution_scorecard_info".
#
# Foreign key violation on row: {'UNITID': 497116, 'YEAR': 2021, 'INSTNM': 'Galen Health Institutes-Austin Campus', 'ADDR': '1201 W. Louis Henna Boulevard', 'CITY': 'Austin', 'STABBR': 'TX', 'ZIP': '78781-2301', 'FIPS': 48, 'COUNTYCD': 48491, 'COUNTYNM': 'Williamson County', 'CBSA': 12420, 'CBSATYPE': 1, 'CSA': -2, 'LATITUDE': 30.476575, 'LONGITUD': -97.690907, 'C21BASIC': -2, 'C21IPUG': -2, 'C21IPGRD': -2, 'C21UGPRF': -2, 'C21ENPRF': -2, 'C21SZSET': -2}
# insert or update on table "institution_ipeds_info" violates foreign key constraint "fk_ipeds_scorecard"
# DETAIL:  Key (unitid, year)=(497116, 2021) is not present in table "institution_scorecard_info".
#
# Foreign key violation on row: {'UNITID': 497125, 'YEAR': 2021, 'INSTNM': 'Galen Health Institutes-Nashville Campus', 'ADDR': '1100 Dr. Martin Luther King Jr Blvd', 'CITY': 'Nashville', 'STABBR': 'TN', 'ZIP': '37203-5755', 'FIPS': 47, 'COUNTYCD': 47037, 'COUNTYNM': 'Davidson County', 'CBSA': 34980, 'CBSATYPE': 1, 'CSA': 400, 'LATITUDE': 36.162229, 'LONGITUD': -86.791569, 'C21BASIC': -2, 'C21IPUG': -2, 'C21IPGRD': -2, 'C21UGPRF': -2, 'C21ENPRF': -2, 'C21SZSET': -2}
# insert or update on table "institution_ipeds_info" violates foreign key constraint "fk_ipeds_scorecard"
# DETAIL:  Key (unitid, year)=(497125, 2021) is not present in table "institution_scorecard_info".
#
# Foreign key violation on row: {'UNITID': 497134, 'YEAR': 2021, 'INSTNM': 'Rasmussen University - Orlando', 'ADDR': '385 Douglas Ave, Suite 1000', 'CITY': 'Altamonte Springs', 'STABBR': 'FL', 'ZIP': '32714-3339', 'FIPS': 12, 'COUNTYCD': 12117, 'COUNTYNM': 'Seminole County', 'CBSA': 36740, 'CBSATYPE': 1, 'CSA': 422, 'LATITUDE': 28.66823, 'LONGITUD': -81.389464, 'C21BASIC': -2, 'C21IPUG': -2, 'C21IPGRD': -2, 'C21UGPRF': -2, 'C21ENPRF': -2, 'C21SZSET': -2}
# insert or update on table "institution_ipeds_info" violates foreign key constraint "fk_ipeds_scorecard"
# DETAIL:  Key (unitid, year)=(497134, 2021) is not present in table "institution_scorecard_info".
#
# Foreign key violation on row: {'UNITID': 497161, 'YEAR': 2021, 'INSTNM': 'Ohio Business College-Dayton-Driving Academy', 'ADDR': '5450 Salem Avenue', 'CITY': 'Trotwood', 'STABBR': 'OH', 'ZIP': '45426', 'FIPS': 39, 'COUNTYCD': 39113, 'COUNTYNM': 'Montgomery County', 'CBSA': 19430, 'CBSATYPE': 1, 'CSA': 212, 'LATITUDE': 39.823721, 'LONGITUD': -84.29184, 'C21BASIC': -2, 'C21IPUG': -2, 'C21IPGRD': -2, 'C21UGPRF': -2, 'C21ENPRF': -2, 'C21SZSET': -2}
# insert or update on table "institution_ipeds_info" violates foreign key constraint "fk_ipeds_scorecard"
# DETAIL:  Key (unitid, year)=(497161, 2021) is not present in table "institution_scorecard_info".
#
# Foreign key violation on row: {'UNITID': 497170, 'YEAR': 2021, 'INSTNM': 'Jersey College - Fort Wayne', 'ADDR': '7836 West Jefferson Boulevard', 'CITY': 'Fort Wayne', 'STABBR': 'IN', 'ZIP': '46804-4680', 'FIPS': 18, 'COUNTYCD': 18003, 'COUNTYNM': 'Allen County', 'CBSA': 23060, 'CBSATYPE': 1, 'CSA': 258, 'LATITUDE': 41.040026, 'LONGITUD': -85.246704, 'C21BASIC': -2, 'C21IPUG': -2, 'C21IPGRD': -2, 'C21UGPRF': -2, 'C21ENPRF': -2, 'C21SZSET': -2}
# insert or update on table "institution_ipeds_info" violates foreign key constraint "fk_ipeds_scorecard"
# DETAIL:  Key (unitid, year)=(497170, 2021) is not present in table "institution_scorecard_info".
#
# Foreign key violation on row: {'UNITID': 497189, 'YEAR': 2021, 'INSTNM': 'The Rapha School', 'ADDR': '17 Griffith Drive', 'CITY': 'Home', 'STABBR': 'PA', 'ZIP': '15747-9615', 'FIPS': 42, 'COUNTYCD': 42063, 'COUNTYNM': 'Indiana County', 'CBSA': 26860, 'CBSATYPE': 2, 'CSA': 430, 'LATITUDE': 40.743997, 'LONGITUD': -79.099123, 'C21BASIC': -2, 'C21IPUG': -2, 'C21IPGRD': -2, 'C21UGPRF': -2, 'C21ENPRF': -2, 'C21SZSET': -2}
# insert or update on table "institution_ipeds_info" violates foreign key constraint "fk_ipeds_scorecard"
# DETAIL:  Key (unitid, year)=(497189, 2021) is not present in table "institution_scorecard_info".
#
# Foreign key violation on row: {'UNITID': 497198, 'YEAR': 2021, 'INSTNM': 'Academy of Allied Health Careers', 'ADDR': '5600 Brainerd Road c-3', 'CITY': 'Chattanooga', 'STABBR': 'TN', 'ZIP': '37411-5336', 'FIPS': 47, 'COUNTYCD': 47065, 'COUNTYNM': 'Hamilton County', 'CBSA': 16860, 'CBSATYPE': 1, 'CSA': 174, 'LATITUDE': 35.008533, 'LONGITUD': -85.214313, 'C21BASIC': -2, 'C21IPUG': -2, 'C21IPGRD': -2, 'C21UGPRF': -2, 'C21ENPRF': -2, 'C21SZSET': -2}
# insert or update on table "institution_ipeds_info" violates foreign key constraint "fk_ipeds_scorecard"
# DETAIL:  Key (unitid, year)=(497198, 2021) is not present in table "institution_scorecard_info".
#
# Foreign key violation on row: {'UNITID': 497204, 'YEAR': 2021, 'INSTNM': 'Mei Barber School', 'ADDR': '205 East Elizabeth Street', 'CITY': 'Brownsville', 'STABBR': 'TX', 'ZIP': '78520-5472', 'FIPS': 48, 'COUNTYCD': 48061, 'COUNTYNM': 'Cameron County', 'CBSA': 15180, 'CBSATYPE': 1, 'CSA': 154, 'LATITUDE': 25.907884, 'LONGITUD': -97.505114, 'C21BASIC': -2, 'C21IPUG': -2, 'C21IPGRD': -2, 'C21UGPRF': -2, 'C21ENPRF': -2, 'C21SZSET': -2}
# insert or update on table "institution_ipeds_info" violates foreign key constraint "fk_ipeds_scorecard"
# DETAIL:  Key (unitid, year)=(497204, 2021) is not present in table "institution_scorecard_info".
#
# Foreign key violation on row: {'UNITID': 497213, 'YEAR': 2021, 'INSTNM': 'Great Northern University', 'ADDR': '611 East Indiana Avenue', 'CITY': 'Spokane', 'STABBR': 'WA', 'ZIP': '99207-2550', 'FIPS': 53, 'COUNTYCD': 53063, 'COUNTYNM': 'Spokane County', 'CBSA': 44060, 'CBSATYPE': 1, 'CSA': 518, 'LATITUDE': 47.675837, 'LONGITUD': -117.400562, 'C21BASIC': -2, 'C21IPUG': -2, 'C21IPGRD': -2, 'C21UGPRF': -2, 'C21ENPRF': -2, 'C21SZSET': -2}
# insert or update on table "institution_ipeds_info" violates foreign key constraint "fk_ipeds_scorecard"
# DETAIL:  Key (unitid, year)=(497213, 2021) is not present in table "institution_scorecard_info".
#
# Foreign key violation on row: {'UNITID': 497222, 'YEAR': 2021, 'INSTNM': 'Salon Professional Academy-Elevate Salon Institute', 'ADDR': '1500 Bay Road Ste C1', 'CITY': 'Miami Beach', 'STABBR': 'FL', 'ZIP': '33139-3252', 'FIPS': 12, 'COUNTYCD': 12086, 'COUNTYNM': 'Miami-Dade County', 'CBSA': 33100, 'CBSATYPE': 1, 'CSA': 370, 'LATITUDE': 25.786328, 'LONGITUD': -80.144449, 'C21BASIC': -2, 'C21IPUG': -2, 'C21IPGRD': -2, 'C21UGPRF': -2, 'C21ENPRF': -2, 'C21SZSET': -2}
# insert or update on table "institution_ipeds_info" violates foreign key constraint "fk_ipeds_scorecard"
# DETAIL:  Key (unitid, year)=(497222, 2021) is not present in table "institution_scorecard_info".
#
# Foreign key violation on row: {'UNITID': 497231, 'YEAR': 2021, 'INSTNM': 'Burlington County Institute of Technology - Adult Education -', 'ADDR': '10 Hawkin Road', 'CITY': 'Medford', 'STABBR': 'NJ', 'ZIP': '08055-0000', 'FIPS': 34, 'COUNTYCD': 34005, 'COUNTYNM': 'Burlington County', 'CBSA': 37980, 'CBSATYPE': 1, 'CSA': 428, 'LATITUDE': 39.894104, 'LONGITUD': -74.803827, 'C21BASIC': -2, 'C21IPUG': -2, 'C21IPGRD': -2, 'C21UGPRF': -2, 'C21ENPRF': -2, 'C21SZSET': -2}
# insert or update on table "institution_ipeds_info" violates foreign key constraint "fk_ipeds_scorecard"
# DETAIL:  Key (unitid, year)=(497231, 2021) is not present in table "institution_scorecard_info".
#
# Foreign key violation on row: {'UNITID': 497240, 'YEAR': 2021, 'INSTNM': 'Shoreline Community College - CNC Machinists Program , Georgetown SSC', 'ADDR': '6737 Corson Avenue South Building A', 'CITY': 'Seattle', 'STABBR': 'WA', 'ZIP': '98108-3450', 'FIPS': 53, 'COUNTYCD': 53033, 'COUNTYNM': 'King County', 'CBSA': 42660, 'CBSATYPE': 1, 'CSA': 500, 'LATITUDE': 47.542457, 'LONGITUD': -122.326138, 'C21BASIC': -2, 'C21IPUG': -2, 'C21IPGRD': -2, 'C21UGPRF': -2, 'C21ENPRF': -2, 'C21SZSET': -2}
# insert or update on table "institution_ipeds_info" violates foreign key constraint "fk_ipeds_scorecard"
# DETAIL:  Key (unitid, year)=(497240, 2021) is not present in table "institution_scorecard_info".
#
# Foreign key violation on row: {'UNITID': 497259, 'YEAR': 2021, 'INSTNM': 'Shoreline Community College - Dental Hygiene', 'ADDR': '1959 Northeast Pacific Street Magnuson HealthSciences Center D232', 'CITY': 'Seattle', 'STABBR': 'WA', 'ZIP': '98195-6365', 'FIPS': 53, 'COUNTYCD': 53033, 'COUNTYNM': 'King County', 'CBSA': 42660, 'CBSATYPE': 1, 'CSA': 500, 'LATITUDE': 47.650612, 'LONGITUD': -122.309103, 'C21BASIC': -2, 'C21IPUG': -2, 'C21IPGRD': -2, 'C21UGPRF': -2, 'C21ENPRF': -2, 'C21SZSET': -2}
# insert or update on table "institution_ipeds_info" violates foreign key constraint "fk_ipeds_scorecard"
# DETAIL:  Key (unitid, year)=(497259, 2021) is not present in table "institution_scorecard_info".
#
# Foreign key violation on row: {'UNITID': 497268, 'YEAR': 2021, 'INSTNM': 'Arizona College of Nursing-Salt Lake City', 'ADDR': '434 West Ascension Way, Suite 122', 'CITY': 'Murray', 'STABBR': 'UT', 'ZIP': '84123-2790', 'FIPS': 49, 'COUNTYCD': 49035, 'COUNTYNM': 'Salt Lake County', 'CBSA': 41620, 'CBSATYPE': 1, 'CSA': 482, 'LATITUDE': 40.656372, 'LONGITUD': -111.903426, 'C21BASIC': -2, 'C21IPUG': -2, 'C21IPGRD': -2, 'C21UGPRF': -2, 'C21ENPRF': -2, 'C21SZSET': -2}
# insert or update on table "institution_ipeds_info" violates foreign key constraint "fk_ipeds_scorecard"
# DETAIL:  Key (unitid, year)=(497268, 2021) is not present in table "institution_scorecard_info".
#
# Foreign key violation on row: {'UNITID': 497277, 'YEAR': 2021, 'INSTNM': 'Arizona College-Glendale', 'ADDR': '4425 West Olive Avenue Suite 300', 'CITY': 'Glendale', 'STABBR': 'AZ', 'ZIP': '85302-3843', 'FIPS': 4, 'COUNTYCD': 4013, 'COUNTYNM': 'Maricopa County', 'CBSA': 38060, 'CBSATYPE': 1, 'CSA': 429, 'LATITUDE': 33.566263, 'LONGITUD': -112.154175, 'C21BASIC': -2, 'C21IPUG': -2, 'C21IPGRD': -2, 'C21UGPRF': -2, 'C21ENPRF': -2, 'C21SZSET': -2}
# insert or update on table "institution_ipeds_info" violates foreign key constraint "fk_ipeds_scorecard"
# DETAIL:  Key (unitid, year)=(497277, 2021) is not present in table "institution_scorecard_info".
#
# Foreign key violation on row: {'UNITID': 497286, 'YEAR': 2021, 'INSTNM': 'Universal Technical Institute-West Texas', 'ADDR': '301 West Howard Lane', 'CITY': 'Austin', 'STABBR': 'TX', 'ZIP': '78753-9742', 'FIPS': 48, 'COUNTYCD': 48453, 'COUNTYNM': 'Travis County', 'CBSA': 12420, 'CBSATYPE': 1, 'CSA': -2, 'LATITUDE': 30.415828, 'LONGITUD': -97.660482, 'C21BASIC': -2, 'C21IPUG': -2, 'C21IPGRD': -2, 'C21UGPRF': -2, 'C21ENPRF': -2, 'C21SZSET': -2}
# insert or update on table "institution_ipeds_info" violates foreign key constraint "fk_ipeds_scorecard"
# DETAIL:  Key (unitid, year)=(497286, 2021) is not present in table "institution_scorecard_info".
#
# Foreign key violation on row: {'UNITID': 497301, 'YEAR': 2021, 'INSTNM': 'Avalon Institute-Las Vegas', 'ADDR': '2650 South Decatur Boulevard Suites 1, 6, 8-10', 'CITY': 'Las Vegas', 'STABBR': 'NV', 'ZIP': '89102-0046', 'FIPS': 32, 'COUNTYCD': 32003, 'COUNTYNM': 'Clark County', 'CBSA': 29820, 'CBSATYPE': 1, 'CSA': 332, 'LATITUDE': 36.142355, 'LONGITUD': -115.206409, 'C21BASIC': -2, 'C21IPUG': -2, 'C21IPGRD': -2, 'C21UGPRF': -2, 'C21ENPRF': -2, 'C21SZSET': -2}
# insert or update on table "institution_ipeds_info" violates foreign key constraint "fk_ipeds_scorecard"
# DETAIL:  Key (unitid, year)=(497301, 2021) is not present in table "institution_scorecard_info".
#
# Foreign key violation on row: {'UNITID': 497310, 'YEAR': 2021, 'INSTNM': 'Medspa Academies-National Institute of Modern Aesthetics', 'ADDR': '3993 Howard Hughes Parkway Suite 150', 'CITY': 'Las Vegas', 'STABBR': 'NV', 'ZIP': '89169-6745', 'FIPS': 32, 'COUNTYCD': 32003, 'COUNTYNM': 'Clark County', 'CBSA': 29820, 'CBSATYPE': 1, 'CSA': 332, 'LATITUDE': 36.117236, 'LONGITUD': -115.158173, 'C21BASIC': -2, 'C21IPUG': -2, 'C21IPGRD': -2, 'C21UGPRF': -2, 'C21ENPRF': -2, 'C21SZSET': -2}
# insert or update on table "institution_ipeds_info" violates foreign key constraint "fk_ipeds_scorecard"
# DETAIL:  Key (unitid, year)=(497310, 2021) is not present in table "institution_scorecard_info".
#
# Foreign key violation on row: {'UNITID': 497329, 'YEAR': 2021, 'INSTNM': 'American Institute-Cherry Hill', 'ADDR': '2201 Route 38 8th Floor', 'CITY': 'Cherry Hill', 'STABBR': 'NJ', 'ZIP': '08002-4309', 'FIPS': 34, 'COUNTYCD': 34007, 'COUNTYNM': 'Camden County', 'CBSA': 37980, 'CBSATYPE': 1, 'CSA': 428, 'LATITUDE': 39.939428, 'LONGITUD': -75.015417, 'C21BASIC': -2, 'C21IPUG': -2, 'C21IPGRD': -2, 'C21UGPRF': -2, 'C21ENPRF': -2, 'C21SZSET': -2}
# insert or update on table "institution_ipeds_info" violates foreign key constraint "fk_ipeds_scorecard"
# DETAIL:  Key (unitid, year)=(497329, 2021) is not present in table "institution_scorecard_info".
#
# Foreign key violation on row: {'UNITID': 497338, 'YEAR': 2021, 'INSTNM': 'Glendale Career College-North-West College-Bakersfield', 'ADDR': '3000 Ming Avenue', 'CITY': 'Bakersfield', 'STABBR': 'CA', 'ZIP': '93304-5075', 'FIPS': 6, 'COUNTYCD': 6029, 'COUNTYNM': 'Kern County', 'CBSA': 12540, 'CBSATYPE': 1, 'CSA': -2, 'LATITUDE': 35.339951, 'LONGITUD': -119.035082, 'C21BASIC': -2, 'C21IPUG': -2, 'C21IPGRD': -2, 'C21UGPRF': -2, 'C21ENPRF': -2, 'C21SZSET': -2}
# insert or update on table "institution_ipeds_info" violates foreign key constraint "fk_ipeds_scorecard"
# DETAIL:  Key (unitid, year)=(497338, 2021) is not present in table "institution_scorecard_info".
#
# Foreign key violation on row: {'UNITID': 497347, 'YEAR': 2021, 'INSTNM': 'University of Maine - Machias', 'ADDR': "116 O'Brien Avenue", 'CITY': 'Machias', 'STABBR': 'ME', 'ZIP': '04654-1397', 'FIPS': 23, 'COUNTYCD': 23029, 'COUNTYNM': 'Washington County', 'CBSA': -2, 'CBSATYPE': -2, 'CSA': -2, 'LATITUDE': 44.708803, 'LONGITUD': -67.458025, 'C21BASIC': -2, 'C21IPUG': -2, 'C21IPGRD': -2, 'C21UGPRF': -2, 'C21ENPRF': -2, 'C21SZSET': -2}
# insert or update on table "institution_ipeds_info" violates foreign key constraint "fk_ipeds_scorecard"
# DETAIL:  Key (unitid, year)=(497347, 2021) is not present in table "institution_scorecard_info".
#
# 6289 rows read successfully.
# 6125 rows loaded successfully.
# 164 rows unsuccessfully loaded.

# %%
conn_string = "postgresql://username:password@localhost:5432/mydb"
insert_dataframe(institution_financial_df, "institution_financial", conn_string)
